# %% [markdown]
# # Query-by-Example (QbE) Search Using DTW

# %% [markdown]
# ## Preliminary

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from __future__ import division
from __future__ import print_function
from os import path
from python_speech_features import delta
from python_speech_features import mfcc
import glob
import matplotlib.pyplot as plt
import numpy as np
import scipy.io.wavfile as wav
import sys
import simpleaudio as sa
from pydub import AudioSegment
from pydub.playback import play
from shennong.audio import Audio
from shennong.features.processor.mfcc import MfccProcessor
from shennong.features.postprocessor.delta import DeltaPostProcessor
from shennong.features.postprocessor.cmvn import CmvnPostProcessor
from progress.bar import Bar
from datetime import datetime
from nltk import word_tokenize
import nltk
nltk.download('punkt')
import Levenshtein as lev
import pickle

sys.path.append("..")
sys.path.append(path.join("..", "utils"))

from speech_dtw import qbe
# Out:
# /home/josh/miniconda3/lib/python3.7/site-packages/pydub/utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# /home/josh/miniconda3/lib/python3.7/site-packages/pydub/utils.py:179: RuntimeWarning: Couldn't find ffplay or avplay - defaulting to ffplay, but may not work
#   warn("Couldn't find ffplay or avplay - defaulting to ffplay, but may not work", RuntimeWarning)
# [nltk_data] Downloading package punkt to /home/josh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Extract features

# %%
def get_mfcc_dd(wav_fn):
    """Return the MFCCs with deltas and delta-deltas for a audio file."""
    audio = Audio.load(wav_fn)
    processor = MfccProcessor(sample_rate=audio.sample_rate, window_type="hamming",frame_length=0.025, frame_shift=0.01,
                              cepstral_lifter=26.0,low_freq=0, vtln_low=60, vtln_high=7200, high_freq=audio.sample_rate/2)
    d_processor = DeltaPostProcessor(order=2)
    mfcc_static = processor.process(audio.channel(1), vtln_warp=1.0)
    mfcc_deltas = d_processor.process(mfcc_static)
    #print(mfcc_static.shape, mfcc_deltas.shape)
    features = mfcc_deltas._to_dict()["data"]
    features = (features - np.mean(features, axis=0)) / np.std(features, axis=0)
    #print(features.shape)
    return features

# %%
#common_words_txt = 'english_words/common_words_500.txt'
#common_words_dir = 'english_words/500_common'
#common_word_wav = 'common_word_*.wav'
topic_words_txt = 'english_words/redfern_words.txt'
topic_words_dir = 'english_words/redfern'
topic_word_wav = 'redfern_words_*.wav'
target_speech_dir = 'redfern'
target_speech_txt = 'redfern_rspk_*.txt'
target_speech_wav = 'redfern_rspk_*.wav'

# %% [markdown]
# ## Take Topic Words

# %%
txt_file = open(topic_words_txt , "r")
word_dict = txt_file.read().split(' ')
redfern_word_list = []
for wav_fn in sorted(glob.glob(path.join("english_words/redfern", "redfern_words_*.wav"))):
    rate, signal = wav.read(wav_fn)
    length = len(signal) / rate * 1000
    query_mfcc = get_mfcc_dd(wav_fn)
    query = {}    
    query["length"] = length
    query["data"] = query_mfcc
    txt_file = open(wav_fn.replace('wav','txt'), "r")
    query["word"] = txt_file.read()
    print(query["word"], end=' ')
    query["audio"] = AudioSegment.from_file(wav_fn, format="wav")
    query["thres"] = 1
    #play(query["audio"])
    redfern_word_list.append(query)
# Out:
# Aboriginal Australia people imagine justice Indigenous recognise Torres Strait social history identity reality beginning failed failure dispossessed Council opportunity fundamental democracy contained problems recognition prejudice living culture generation Islander committed knowledge contemporary demoralisation opponents remarkable traditional ignorance Commission practical partnership continent settlement contributions participation environment confident International significance persecution multicultural

# %%
print(redfern_word_list[3]["word"])
play(redfern_word_list[3]["audio"])
#print(query["data"].shape)
# Out:
# imagine

# %% [markdown]
# ## Take Target Speech Utterances

# %%
redfern_rspk = []
for wav_fn in sorted(glob.glob(path.join(target_speech_dir, target_speech_wav))):
    dic = {}
    dic["audio"] = AudioSegment.from_file(wav_fn, format="wav")
    dic["data"] = get_mfcc_dd(wav_fn)
    txt_file = open(wav_fn.replace('wav','txt'), "r")
    dic["word"] = txt_file.read()
    redfern_rspk.append(dic)

print(redfern_rspk[5]['word'])  
play(redfern_rspk[5]['audio'])
# Out:
# This is a fundamental test of our social goals and our national will:

# %%
print(redfern_word_list[10]["word"])
print(redfern_rspk[2]["word"])
#print(redfern_word_list[1]["data"], redfern_rspk[2]["data"])
#print(np.float64(redfern_word_list[1]["data"]), np.float64(redfern_rspk[2]["data"]))
sweep_original = qbe.dtw_sweep(np.float64(redfern_word_list[10]["data"]), np.float64(redfern_rspk[2]["data"]))
plt.plot(sweep_original,color='green')
play(redfern_word_list[10]['audio'])
play(redfern_rspk[2]["audio"])
# Out:
# history
# It will be a year of great significance for Australia.

# %%
print(len(redfern_rspk))
# Out:
# 112

# %%
def get_score(num_uttword, num_spotted, num_match, num_unspotted):
    word_recognition_rate = num_spotted/num_uttword
    precision = num_spotted/num_match
    recall = num_spotted/(num_spotted+num_unspotted)
    return word_recognition_rate, precision, recall

# %%
from tqdm import tqdm
from statistics import mean
result = []
num_uttword = 0.01
num_spotted = 0.01 
num_prediction = 0.01
num_unspotted = 0.01
thres_distance = 0
common_words_penalty = 1.2
correct_dtw_score = []
incorrect_dtw_score = []

for uttr in range(0,len(redfern_rspk)):
    dic = {}
    dic['correct_words'] = []
    dic['incorrect_words'] = []
    dic['correct_dtw'] = []
    dic['incorrect_dtw'] = []
    match = set()
    close_words = set()
    for query in redfern_word_list:        
        query_word = query["word"].lower()
        query_mfcc = np.float64(query["data"])
        search_mfcc = np.float64(redfern_rspk[uttr]["data"])
        dtw_costs = qbe.dtw_sweep(query_mfcc, search_mfcc)
        min_dtw = np.min(dtw_costs)
        utt_sent = word_tokenize(redfern_rspk[uttr]['word'].lower())
        hasMatch = False
        dic['sentence'] = utt_sent                
                
        for utt_word in utt_sent:
            if lev.distance(query_word,utt_word)<=thres_distance:
                dic['correct_words'].append(utt_word)
                dic['correct_dtw'].append(min_dtw)
                correct_dtw_score.append(min_dtw)
                dic['time']=dtw_costs.index(min_dtw)*3/100
                print('{:<20}'.format(utt_word), end=' ')
                print('{:<20}'.format(query_word), end=' ')
                print("%0.3f" % min_dtw, end='\t')
                print(dic['time'])
                hasMatch = True
                #print('spotted_words:')
                #print(query_word,min_dtw)
                break
                
        if hasMatch == False:
            dic['incorrect_words'].append(query_word)
            dic['incorrect_dtw'].append(min_dtw)
            incorrect_dtw_score.append(min_dtw)
            #print('incorrect_words:')
            #print(query_word,min_dtw)        
        
    num_uttword += len(nltk.FreqDist(utt_sent))
    #num_prediction += len(match)
    num_spotted += len(dic['correct_words'])
    num_unspotted += len(dic['incorrect_words'])

#    print('Utterance: \t'+redfern_rspk[uttr]['word'])
#    print('Spotted Words:', end='\t')
#    for query_word ,word in close_words:
#        print('('+query_word+', '+word+')', end=' ')  
#    for word in dic['spotted_words']:
#        print(word, end=' ') 
#    print('\nFalse Positive:', end='\t')
#    for word in dic['incorrect_words']:
#        print(word, end=' ')
#    print('\nFailed to Spot:', end='\t')
#    for word in dic['unspotted_words']:
#        print(word, end=' ')
#    print('\n') 
    #word_recognition_rate, precision, recall = get_score(num_uttword, num_spotted, num_prediction, num_unspotted)     
    result.append(dic)
    if len(correct_dtw_score)>0:
        print('\nCorrect DTW Average:', end=' ')
        print(mean(correct_dtw_score))
    print('Incorrect DTW Average:', end=' ')
    print(mean(incorrect_dtw_score))
    print('\n') 
    
print('\nCoverage: \t'+str(word_recognition_rate))
print('Precision: \t'+str(precision))
print('Recall: \t'+str(recall))
print('\n')
# Out:
# Incorrect DTW Average: 0.3816614955329538
#
#
# australia            australia            0.254	5.88
# people               people               0.335	15.72
# indigenous           indigenous           0.283	14.91
# international        international        0.254	11.28
#
# Correct DTW Average: 0.28154961044635207
# Incorrect DTW Average: 0.3634108969085471
#
#
# australia            australia            0.277	3.81
# significance         significance         0.291	2.49
#
# Correct DTW Average: 0.2824128366518749
# Incorrect DTW Average: 0.3647959791158007
#
#
# failed               failed               0.262	11.82
# committed            committed            0.278	3.48
#
# Correct DTW Average: 0.2793659531086553
# Incorrect DTW Average: 0.3613178283455755
#
#
# aboriginal           aboriginal           0.235	23.64
# australia            australia            0.213	21.72
# people               people               0.283	20.79
# indigenous           indigenous           0.304	19.92
# torres               torres               0.217	25.41
# strait               strait               0.228	25.89
# opportunity          opportunity          0.201	13.83
#
# Correct DTW Average: 0.2609788395283552
# Incorrect DTW Average: 0.3575565640392053
#
#
# social               social               0.211	4.5
# fundamental          fundamental          0.243	1.29
#
# Correct DTW Average: 0.2569447463613853
# Incorrect DTW Average: 0.35794113370157554
#
#
# australia            australia            0.216	6.45
# social               social               0.232	10.26
# democracy            democracy            0.248	11.01
#
# Correct DTW Average: 0.2531782346546584
# Incorrect DTW Average: 0.3556238440149002
#
#
#
# Correct DTW Average: 0.2531782346546584
# Incorrect DTW Average: 0.3567059042363977
#
#
#
# Correct DTW Average: 0.2531782346546584
# Incorrect DTW Average: 0.35782583928529116
#
#
#
# Correct DTW Average: 0.2531782346546584
# Incorrect DTW Average: 0.36027381539770514
#
#
# history              history              0.249	2.13
#
# Correct DTW Average: 0.25297546080690264
# Incorrect DTW Average: 0.3623800618522762
#
#
# aboriginal           aboriginal           0.271	6.9
# australia            australia            0.209	4.95
# recognise            recognise            0.248	10.47
# beginning            beginning            0.266	9.24
# contained            contained            0.212	12.99
#
# Correct DTW Average: 0.2507161174280161
# Incorrect DTW Average: 0.36112999783402333
#
#
# indigenous           indigenous           0.251	6.06
# beginning            beginning            0.267	1.98
# living               living               0.317	11.82
#
# Correct DTW Average: 0.2535693142620517
# Incorrect DTW Average: 0.3602154901363461
#
#
# aboriginal           aboriginal           0.285	6.87
# imagine              imagine              0.286	5.07
#
# Correct DTW Average: 0.2556379177106553
# Incorrect DTW Average: 0.359664211751908
#
#
#
# Correct DTW Average: 0.2556379177106553
# Incorrect DTW Average: 0.3618115944479918
#
#
# reality              reality              0.219	7.2
#
# Correct DTW Average: 0.2544806042818213
# Incorrect DTW Average: 0.3613741379943448
#
#
# imagine              imagine              0.274	3.87
#
# Correct DTW Average: 0.255073101278105
# Incorrect DTW Average: 0.3618728716559749
#
#
# people               people               0.252	5.16
# imagine              imagine              0.284	1.44
# culture              culture              0.265	12.3
# environment          environment          0.307	24.93
#
# Correct DTW Average: 0.25745750895424196
# Incorrect DTW Average: 0.36022205320612843
#
#
# imagine              imagine              0.277	1.5
#
# Correct DTW Average: 0.2579635591122521
# Incorrect DTW Average: 0.36117928759804857
#
#
# imagine              imagine              0.258	1.56
#
# Correct DTW Average: 0.25797494381908087
# Incorrect DTW Average: 0.3616063366549758
#
#
# confident            confident            0.238	5.79
#
# Correct DTW Average: 0.25746351441554993
# Incorrect DTW Average: 0.36150538004683014
#
#
# aboriginal           aboriginal           0.222	12.75
# australia            australia            0.181	13.77
# recognise            recognise            0.222	1.44
# identity             identity             0.274	7.29
# contemporary         contemporary         0.290	6.15
#
# Correct DTW Average: 0.25528249773054174
# Incorrect DTW Average: 0.3606077746871272
#
#
# confident            confident            0.267	0.87
#
# Correct DTW Average: 0.255547152600576
# Incorrect DTW Average: 0.36086753690721507
#
#
#
# Correct DTW Average: 0.255547152600576
# Incorrect DTW Average: 0.3631370623284024
#
#
# aboriginal           aboriginal           0.220	2.91
# australia            australia            0.207	6.42
#
# Correct DTW Average: 0.25378545152690185
# Incorrect DTW Average: 0.36289913167660737
#
#
#
# Correct DTW Average: 0.25378545152690185
# Incorrect DTW Average: 0.3626783193604508
#
#
# aboriginal           aboriginal           0.222	20.04
# australia            australia            0.207	21.03
# failure              failure              0.323	11.49
# demoralisation       demoralisation       0.244	17.43
#
# Correct DTW Average: 0.25339017465387137
# Incorrect DTW Average: 0.36213692154267646
#
#
# aboriginal           aboriginal           0.230	7.8
# recognise            recognise            0.223	4.56
#
# Correct DTW Average: 0.25240227424283174
# Incorrect DTW Average: 0.36177389220799466
#
#
# aboriginal           aboriginal           0.257	7.38
# australia            australia            0.226	8.52
# reality              reality              0.225	6.3
# contained            contained            0.257	12.15
#
# Correct DTW Average: 0.2516398911540157
# Incorrect DTW Average: 0.361421652051266
#
#
# contained            contained            0.270	10.26
#
# Correct DTW Average: 0.2519582404779762
# Incorrect DTW Average: 0.36137220017641924
#
#
# australia            australia            0.204	6.93
#
# Correct DTW Average: 0.25115876240418683
# Incorrect DTW Average: 0.3611399418203058
#
#
# people               people               0.246	8.55
# indigenous           indigenous           0.251	7.59
#
# Correct DTW Average: 0.25107045189985333
# Incorrect DTW Average: 0.361339851394109
#
#
# indigenous           indigenous           0.296	13.74
# recognise            recognise            0.252	6.6
# identity             identity             0.221	26.61
# dispossessed         dispossessed         0.237	2.1
#
# Correct DTW Average: 0.25111185738765746
# Incorrect DTW Average: 0.36074343063790143
#
#
# australia            australia            0.188	9.54
#
# Correct DTW Average: 0.25016452282542984
# Incorrect DTW Average: 0.3607601397572061
#
#
#
# Correct DTW Average: 0.25016452282542984
# Incorrect DTW Average: 0.36076912789494486
#
#
# people               people               0.255	13.62
#
# Correct DTW Average: 0.2502332616607218
# Incorrect DTW Average: 0.3607155487745458
#
#
#
# Correct DTW Average: 0.2502332616607218
# Incorrect DTW Average: 0.3602662154219636
#
#
# social               social               0.233	16.86
# failure              failure              0.297	8.1
# dispossessed         dispossessed         0.245	26.1
# problems             problems             0.325	3.18
# contemporary         contemporary         0.244	13.14
# opponents            opponents            0.341	2.94
#
# Correct DTW Average: 0.25271936961044306
# Incorrect DTW Average: 0.3598852757522134
#
#
# history              history              0.290	7.56
#
# Correct DTW Average: 0.25321190383230174
# Incorrect DTW Average: 0.3598823400568612
#
#
# australia            australia            0.203	7.71
#
# Correct DTW Average: 0.2525447305034392
# Incorrect DTW Average: 0.3598374280446359
#
#
# australia            australia            0.237	0.63
# dispossessed         dispossessed         0.218	6.48
# opportunity          opportunity          0.190	2.55
#
# Correct DTW Average: 0.2511233530136124
# Incorrect DTW Average: 0.3597952646288367
#
#
#
# Correct DTW Average: 0.2511233530136124
# Incorrect DTW Average: 0.3603450682421463
#
#
# persecution          persecution          0.212	4.35
#
# Correct DTW Average: 0.2506368580406367
# Incorrect DTW Average: 0.3603067688972528
#
#
# australia            australia            0.201	14.22
# people               people               0.266	28.23
# problems             problems             0.268	21.45
# remarkable           remarkable           0.275	7.83
# multicultural        multicultural        0.220	10.86
#
# Correct DTW Average: 0.25037371519337204
# Incorrect DTW Average: 0.359822388475222
#
#
# recognise            recognise            0.258	6.0
#
# Correct DTW Average: 0.250459018397121
# Incorrect DTW Average: 0.35943166167178253
#
#
# recognition          recognition          0.250	6.24
#
# Correct DTW Average: 0.25045617021014555
# Incorrect DTW Average: 0.35943546551667854
#
#
# traditional          traditional          0.253	1.47
#
# Correct DTW Average: 0.25048820116760556
# Incorrect DTW Average: 0.35942912629597384
#
#
#
# Correct DTW Average: 0.25048820116760556
# Incorrect DTW Average: 0.35970279199720107
#
#
# committed            committed            0.279	0.0
#
# Correct DTW Average: 0.25080643490478766
# Incorrect DTW Average: 0.36030337064313506
#
#
#
# Correct DTW Average: 0.25080643490478766
# Incorrect DTW Average: 0.36051106373293723
#
#
#
# Correct DTW Average: 0.25080643490478766
# Incorrect DTW Average: 0.3605593038729073
#
#
# imagine              imagine              0.284	8.67
# failure              failure              0.274	7.23
# prejudice            prejudice            0.205	4.71
# ignorance            ignorance            0.240	1.95
#
# Correct DTW Average: 0.25080247836878045
# Incorrect DTW Average: 0.36047347886864184
#
#
# failed               failed               0.213	3.75
#
# Correct DTW Average: 0.2504015484826901
# Incorrect DTW Average: 0.3603368155261658
#
#
# failed               failed               0.272	0.54
#
# Correct DTW Average: 0.2506255165492679
# Incorrect DTW Average: 0.3603462612714275
#
#
# failed               failed               0.285	2.55
#
# Correct DTW Average: 0.2509798541962518
# Incorrect DTW Average: 0.360292958935559
#
#
# aboriginal           aboriginal           0.261	33.93
# identity             identity             0.201	44.22
# prejudice            prejudice            0.259	30.21
# demoralisation       demoralisation       0.266	38.79
# ignorance            ignorance            0.219	31.77
# commission           commission           0.316	10.62
#
# Correct DTW Average: 0.25113758397021285
# Incorrect DTW Average: 0.35976314782573265
#
#
#
# Correct DTW Average: 0.25113758397021285
# Incorrect DTW Average: 0.3598482457201463
#
#
#
# Correct DTW Average: 0.25113758397021285
# Incorrect DTW Average: 0.35995280425771337
#
#
#
# Correct DTW Average: 0.25113758397021285
# Incorrect DTW Average: 0.36003203343205736
#
#
#
# Correct DTW Average: 0.25113758397021285
# Incorrect DTW Average: 0.3600911935034067
#
#
#
# Correct DTW Average: 0.25113758397021285
# Incorrect DTW Average: 0.3601821395359687
#
#
# recognise            recognise            0.206	1.65
# practical            practical            0.248	10.86
#
# Correct DTW Average: 0.25067327673618245
# Incorrect DTW Average: 0.3600188828204582
#
#
# aboriginal           aboriginal           0.238	7.44
# council              council              0.187	6.09
#
# Correct DTW Average: 0.24995053364378034
# Incorrect DTW Average: 0.3599014123575262
#
#
# australia            australia            0.246	15.81
# people               people               0.301	17.79
# justice              justice              0.236	7.05
# indigenous           indigenous           0.270	16.98
# council              council              0.206	0.24
# partnership          partnership          0.248	4.68
#
# Correct DTW Average: 0.2500264880951229
# Incorrect DTW Average: 0.359795800231741
#
#
#
# Correct DTW Average: 0.2500264880951229
# Incorrect DTW Average: 0.360070765138963
#
#
# justice              justice              0.181	3.03
#
# Correct DTW Average: 0.24941993012460636
# Incorrect DTW Average: 0.3598079833310942
#
#
# living               living               0.281	2.07
#
# Correct DTW Average: 0.2496944585582668
# Incorrect DTW Average: 0.35987180113387995
#
#
#
# Correct DTW Average: 0.2496944585582668
# Incorrect DTW Average: 0.35987959554144655
#
#
#
# Correct DTW Average: 0.2496944585582668
# Incorrect DTW Average: 0.3600599454128637
#
#
#
# Correct DTW Average: 0.2496944585582668
# Incorrect DTW Average: 0.3599003671588268
#
#
# practical            practical            0.225	1.62
#
# Correct DTW Average: 0.24948348842497012
# Incorrect DTW Average: 0.3599702706411687
#
#
# justice              justice              0.253	28.47
# fundamental          fundamental          0.270	23.25
# continent            continent            0.240	12.3
# settlement           settlement           0.273	17.25
#
# Correct DTW Average: 0.24980169201937072
# Incorrect DTW Average: 0.35971730201743163
#
#
#
# Correct DTW Average: 0.24980169201937072
# Incorrect DTW Average: 0.3596809080440132
#
#
#
# Correct DTW Average: 0.24980169201937072
# Incorrect DTW Average: 0.35950904178474596
#
#
# indigenous           indigenous           0.207	14.01
#
# Correct DTW Average: 0.24944659511674652
# Incorrect DTW Average: 0.3591937896479742
#
#
# justice              justice              0.252	13.83
# indigenous           indigenous           0.277	23.22
# social               social               0.237	13.11
# democracy            democracy            0.249	20.22
# recognition          recognition          0.292	6.99
#
# Correct DTW Average: 0.24991999220571548
# Incorrect DTW Average: 0.35903821729326785
#
#
#
# Correct DTW Average: 0.24991999220571548
# Incorrect DTW Average: 0.35930535480559156
#
#
#
# Correct DTW Average: 0.24991999220571548
# Incorrect DTW Average: 0.35950974185996903
#
#
# aboriginal           aboriginal           0.279	0.63
# australia            australia            0.239	6.63
# remarkable           remarkable           0.264	9.63
# contributions        contributions        0.269	13.92
#
# Correct DTW Average: 0.2503227550937302
# Incorrect DTW Average: 0.359314455009364
#
#
# australia            australia            0.195	7.2
# history              history              0.235	6.03
#
# Correct DTW Average: 0.24977956565133588
# Incorrect DTW Average: 0.3592930308185071
#
#
#
# Correct DTW Average: 0.24977956565133588
# Incorrect DTW Average: 0.3592465765891907
#
#
# knowledge            knowledge            0.235	4.23
# continent            continent            0.239	5.85
#
# Correct DTW Average: 0.24958388863656208
# Incorrect DTW Average: 0.35921743378765897
#
#
# identity             identity             0.224	2.64
#
# Correct DTW Average: 0.24939195272783937
# Incorrect DTW Average: 0.3594181856643399
#
#
#
# Correct DTW Average: 0.24939195272783937
# Incorrect DTW Average: 0.3594237034666626
#
#
# justice              justice              0.200	3.3
# partnership          partnership          0.271	10.47
#
# Correct DTW Average: 0.24918060677111345
# Incorrect DTW Average: 0.3594251396297798
#
#
# dispossessed         dispossessed         0.256	9.42
#
# Correct DTW Average: 0.24923018243998846
# Incorrect DTW Average: 0.3592014202579693
#
#
# imagine              imagine              0.279	0.0
# culture              culture              0.343	4.17
#
# Correct DTW Average: 0.25012002262937594
# Incorrect DTW Average: 0.35919204640588576
#
#
# imagine              imagine              0.233	0.0
# history              history              0.328	14.13
# settlement           settlement           0.270	4.5
#
# Correct DTW Average: 0.25068454261984807
# Incorrect DTW Average: 0.35905844516701896
#
#
# imagine              imagine              0.274	0.0
# history              history              0.324	12.6
#
# Correct DTW Average: 0.2513504336444696
# Incorrect DTW Average: 0.35894720782563194
#
#
# imagine              imagine              0.278	0.0
# prejudice            prejudice            0.221	16.56
#
# Correct DTW Average: 0.25132917693901147
# Incorrect DTW Average: 0.35888417987454996
#
#
# imagine              imagine              0.267	0.0
#
# Correct DTW Average: 0.25143414038633183
# Incorrect DTW Average: 0.3588847382300042
#
#
# imagine              imagine              0.249	0.0
#
# Correct DTW Average: 0.25141880092166735
# Incorrect DTW Average: 0.3588448209666138
#
#
# imagine              imagine              0.251	7.35
#
# Correct DTW Average: 0.2514151551934512
# Incorrect DTW Average: 0.3588134138284757
#
#
# justice              justice              0.239	2.07
#
# Correct DTW Average: 0.2513324460857463
# Incorrect DTW Average: 0.3590984069418358
#
#
# justice              justice              0.371	1.98
#
# Correct DTW Average: 0.2521263564685227
# Incorrect DTW Average: 0.3592432351648079
#
#
# justice              justice              0.251	14.4
# social               social               0.221	7.29
# fundamental          fundamental          0.186	11.67
# democracy            democracy            0.222	8.76
#
# Correct DTW Average: 0.2512936157160928
# Incorrect DTW Average: 0.35912600559448016
#
#
# opportunity          opportunity          0.166	19.14
# participation        participation        0.216	17.55
#
# Correct DTW Average: 0.25052972087466496
# Incorrect DTW Average: 0.3590191805458917
#
#
# australia            australia            0.190	17.94
# reality              reality              0.178	25.56
# living               living               0.274	2.25
# generation           generation           0.296	21.12
#
# Correct DTW Average: 0.25013260081982425
# Incorrect DTW Average: 0.35886276131751604
#
#
# reality              reality              0.229	6.18
#
# Correct DTW Average: 0.25000164186062146
# Incorrect DTW Average: 0.3588144150064386
#
#
#
# Correct DTW Average: 0.25000164186062146
# Incorrect DTW Average: 0.35879844271649736
#
#
# council              council              0.220	4.65
#
# Correct DTW Average: 0.24981716681399804
# Incorrect DTW Average: 0.3588113759444389
#
#
#
# Correct DTW Average: 0.24981716681399804
# Incorrect DTW Average: 0.35889094096904545
#
#
# aboriginal           aboriginal           0.237	0.6
# torres               torres               0.256	2.01
# strait               strait               0.251	2.52
# islander             islander             0.294	3.06
# commission           commission           0.299	3.84
#
# Correct DTW Average: 0.2503427363170217
# Incorrect DTW Average: 0.35881811724469276
#
#
# council              council              0.232	0.42
#
# Correct DTW Average: 0.2502356419889848
# Incorrect DTW Average: 0.3588751796831838
#
#
# indigenous           indigenous           0.261	5.49
#
# Correct DTW Average: 0.25029987597378955
# Incorrect DTW Average: 0.35886655512806187
#
#
# aboriginal           aboriginal           0.243	7.98
# reality              reality              0.251	3.96
#
# Correct DTW Average: 0.25025728971553785
# Incorrect DTW Average: 0.3587205716474937
#
#
# aboriginal           aboriginal           0.213	3.0
# australia            australia            0.217	1.32
# torres               torres               0.204	4.74
# strait               strait               0.282	5.52
# islander             islander             0.296	6.09
#
# Correct DTW Average: 0.2500349974916328
# Incorrect DTW Average: 0.35866803096585737
#
#
# problems             problems             0.282	2.55
#
# Correct DTW Average: 0.2502126581897832
# Incorrect DTW Average: 0.3586248971996412
#
#
# aboriginal           aboriginal           0.242	12.42
# culture              culture              0.241	13.38
# generation           generation           0.224	22.05
#
# Correct DTW Average: 0.24997607154768686
# Incorrect DTW Average: 0.358464196055926
#
#
# aboriginal           aboriginal           0.250	9.3
# torres               torres               0.245	10.77
# strait               strait               0.258	11.22
# beginning            beginning            0.233	0.9
# islander             islander             0.258	12.06
#
# Correct DTW Average: 0.24994439204581811
# Incorrect DTW Average: 0.3584038571404694
#
#
# aboriginal           aboriginal           0.235	17.25
# people               people               0.358	5.82
# recognise            recognise            0.257	6.27
# torres               torres               0.243	19.08
# strait               strait               0.269	19.86
# identity             identity             0.229	11.7
# beginning            beginning            0.257	4.98
# participation        participation        0.278	15.06
#
# Correct DTW Average: 0.2505842710493049
# Incorrect DTW Average: 0.3583134499604001
#
#
# people               people               0.224	4.59
# indigenous           indigenous           0.282	3.72
# beginning            beginning            0.261	0.96
# environment          environment          0.275	13.65
#
# Correct DTW Average: 0.25078440776670957
# Incorrect DTW Average: 0.3582355837378926
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-bbf1d65772e6> in <module>
#      78     print('\n')
#      79
# ---> 80 print('\nCoverage: \t'+str(word_recognition_rate))
#      81 print('Precision: \t'+str(precision))
#      82 print('Recall: \t'+str(recall))
#
# NameError: name 'word_recognition_rate' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.kdeplot(dic['correct_dtw'], shade=True, linewidth = 3, label = 'Correct words')
sns.kdeplot(dic['incorrect_dtw'], shade=True, linewidth = 3, label = 'Incorrect words')
    
# Plot formatting
plt.legend(prop={'size': 12})
plt.title('Search Query DTW Cost Distribution w/ 50 Topic Words')
plt.xlabel('DTW Cost')
plt.ylabel('Density')
plt.savefig('redfern_rspk_topic_dtw.png', dpi=400)

# %%
print(num_uttword, num_spotted, num_prediction, num_unspotted)
# Out:
# 1931.01 190.01 295.01 14.01

# %%
with open('redfern_rspk_topic_words.data', 'wb') as filehandle:
    pickle.dump(result, filehandle)
